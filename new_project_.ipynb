# %% [markdown]
# <a href="https://colab.research.google.com/github/subhabatul-maker/demo_pro/blob/main/new_project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# smart grade calculator
print("---smart grade calculator---")

name = input("enter the name of the student: ")

sub1 = float(input("enter the marks of subject 1: "))
sub2 = float(input("enter the marks of subject 2: "))
sub3 = float(input("enter the marks of subject 3: "))
sub4 = float(input("enter the marks of subject 4: "))
sub5 = float(input("enter the marks of subject 5: "))

total = sub1 + sub2 + sub3 + sub4 + sub5
avg = total / 5

if avg >= 90:
    grade = "A+"
elif avg >= 80:
    grade = "A"
elif avg >= 70:
    grade = "B"
elif avg >= 60:
    grade = "C"
elif avg >= 50:
    grade = "D"
else:
    grade = "Fail"

print("\n---result---")
print("student name:", name)
print("total marks:", total)
print("average marks:", avg)
print("grade:", grade)
# Out:
# ---smart grade calculator---
# enter the name of the student: shubha
# enter the marks of subject 1: 70
# enter the marks of subject 2: 88
# enter the marks of subject 3: 90
# enter the marks of subject 4: 55
# enter the marks of subject 5: 60
#
# ---result---
# student name: shubha
# total marks: 363.0
# average marks: 72.6
# grade: B

# %%
# simple calculator app
print("---simple calculator app---")

num1 = float(input("enter the first number: "))
num2 = float(input("enter the second number: "))

print("\nchoose operation:")
print("1. addition")
print("2. subtraction")
print("3. multiplication")
print("4. division")

choice = int(input("enter your choice (1/2/3/4): "))

if choice == 1:
    print("addition:", num1 + num2)

elif choice == 2:
    print("subtraction:", num1 - num2)

elif choice == 3:
    print("multiplication:", num1 * num2)

elif choice == 4:
    if num2 != 0:
        print("division:", num1 / num2)
    else:
        print(" division by zero is not allowed")

else:
    print(" invalid choice")
# Out:
# ---simple calculator app---
# enter the first number: 23
# enter the second number: 33
#
# choose operation:
# 1. addition
# 2. subtraction
# 3. multiplication
# 4. division
# enter your choice (1/2/3/4): 3
# multiplication: 759.0

# %%
# contact book mini project
contacts = {}
while True :
  print("\n=== contact book ===")
  print("1. add contact")
  print("2. view contacts")
  print("3. search contact")
  print("5. delete contact")
  print("6. exit")
  choice = input("enter your choice : ")
  if choice == "1":
    name = input("enter the name : ")
    phone = input("enter the phone number : ")
